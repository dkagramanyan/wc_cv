# %%
from combra import data, image

# %% [markdown]
# # Splitting and rotating images

# %%
input_folder = '../datasets/original/o_bc_left'
output_folder = '../datasets/original/o_bc_left_9x_512'

image.split_rotate(input_folder, output_folder)
# Out:
# <function combra.image.preprocess.split_rotate(input_folder, output_folder, split=3, rotate=False)>

# %% [markdown]
# # EDT

# %%
image.do_edt()

# %% [markdown]
# # Resize

# %%
input_root = "/media/david/work_ssd_2_sata/python/wc_cv/datasets/diffusion/o_bc_left_4x_768_360_median" # Replace with your input directory
output_root = "/media/david/work_ssd_2_sata/python/wc_cv/datasets/diffusion/o_bc_left_4x_768_360_median_rgb_256" # Replace with your output directory

target_size=(256,256)

image.rezise(input_root, output_root, target_size)
